# %%
from config import api_key, url, get, state
import requests
import pandas as pd
import numpy as np
import json
import csv
import matplotlib.pyplot as plt

import pprint

# %%
#read the census csv
file = "nst-est2019-alldata.csv"
file2 = "nst-est2019-popchg2010_2019.csv"
file3 = "csa-est2019-alldata.csv"
df= pd.read_csv(file)
df2 = pd.read_csv(file2)
df3 = pd.read_csv(file3)
df
# Out:
#     SUMLEV REGION DIVISION  STATE                  NAME  CENSUS2010POP  \
# 0       10      0        0      0         United States      308745538
# 1       20      1        0      0      Northeast Region       55317240
# 2       20      2        0      0        Midwest Region       66927001
# 3       20      3        0      0          South Region      114555744
# 4       20      4        0      0           West Region       71945553
# 5       40      3        6      1               Alabama        4779736
# 6       40      4        9      2                Alaska         710231
# 7       40      4        8      4               Arizona        6392017
# 8       40      3        7      5              Arkansas        2915918
# 9       40      4        9      6            California       37253956
# 10      40      4        8      8              Colorado        5029196
# 11      40      1        1      9           Connecticut        3574097
# ...

# %%
#read the covid-19 api

url = "https://covid-19-coronavirus-statistics.p.rapidapi.com/v1/stats"

querystring = {"country":"Us"}

headers = {
    'x-rapidapi-host': "covid-19-coronavirus-statistics.p.rapidapi.com",
    'x-rapidapi-key': "65d537c6fcmsh9cb598676e881e3p17190cjsnded08a705dc3"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
j = response.json()
j
# Out:
# {'error': False,
#  'statusCode': 200,
#  'message': 'Country not found. Returning all stats. Please use a country name found in the data property.',
#  'data': {'lastChecked': '2020-04-15T03:06:19.872Z',
#   'covid19Stats': [{'city': 'Abbeville',
#     'province': 'South Carolina',
#     'country': 'US',
#     'lastUpdate': '2020-04-14 23:33:31',
#     'keyId': 'Abbeville, South Carolina, US',
#     'confirmed': 9,
#     'deaths': 0,
#     'recovered': 0},
#    {'city': 'Acadia',
#     'province': 'Louisiana',
#     'country': 'US',
#     'lastUpdate': '2020-04-14 23:33:31',
#     'keyId': 'Acadia, Louisiana, US',
#     'confirmed': 104,
#     'deaths': 5,
#     'recovered': 0},
#    {'city': 'Accomack',
#     'province': 'Virginia',
#     'country': 'US',
#     'lastUpdate': '2020-04-14 23:33:31',
#     'keyId': 'Accomack, Virginia, US',
#     'confirmed': 15,
#     'deaths': 0,
#     'recovered': 0},
#    {'city': 'Ada',
#     'province': 'Idaho',
#     'country': 'US',
# ...

# %%
#pulling out confirmed cases on california
gen = j["data"]["covid19Stats"]
i = 0

user_input = input("Enter a state name: ").title()
print(f'State name entered: {user_input}')

for i in range(len(gen)):
    if gen[i]["province"] == user_input:
    
    #print(gen[i]['province'])
        #print(f'city of confirmed case:{gen[i]["city"]}')
        print(f'{gen[i]["city"]} has {gen[i]["confirmed"]} confirmed Cases.')
    i+=1
# Out:
# Enter a state name: california
# State name entered: California
# Alameda has 888 confirmed Cases.
# Alpine has 2 confirmed Cases.
# Amador has 7 confirmed Cases.
# Butte has 15 confirmed Cases.
# Calaveras has 9 confirmed Cases.
# Colusa has 3 confirmed Cases.
# Contra Costa has 552 confirmed Cases.
# Del Norte has 2 confirmed Cases.
# El Dorado has 34 confirmed Cases.
# Fresno has 222 confirmed Cases.
# Glenn has 4 confirmed Cases.
# Humboldt has 50 confirmed Cases.
# Imperial has 100 confirmed Cases.
# Inyo has 12 confirmed Cases.
# Kern has 462 confirmed Cases.
# Kings has 12 confirmed Cases.
# Lake has 4 confirmed Cases.
# Los Angeles has 10047 confirmed Cases.
# Madera has 33 confirmed Cases.
# Marin has 170 confirmed Cases.
# Mendocino has 4 confirmed Cases.
# Merced has 74 confirmed Cases.
# Mono has 23 confirmed Cases.
# Monterey has 87 confirmed Cases.
# Napa has 38 confirmed Cases.
# Nevada has 34 confirmed Cases.
# Orange has 1299 confirmed Cases.
# ...

# %%
j = 0
list0= []
list1= [[]]
for j in range(len(df['NAME'])):
    print(f'Name: {df["NAME"][j]}, Population: {df["POPESTIMATE2012"][j]}')
    for lists in list1:
        lists.append(df["POPESTIMATE2012"][j])
    
    j+=1
print(lists)
# Out:
# Name: United States, Population: 313830990
# Name: Northeast Region, Population: 55775216
# Name: Midwest Region, Population: 67336743
# Name: South Region, Population: 117241208
# Name: West Region, Population: 73477823
# Name: Alabama, Population: 4815588
# Name: Alaska, Population: 730443
# Name: Arizona, Population: 6554978
# Name: Arkansas, Population: 2952164
# Name: California, Population: 37948800
# Name: Colorado, Population: 5192647
# Name: Connecticut, Population: 3594547
# Name: Delaware, Population: 915179
# Name: District of Columbia, Population: 634924
# Name: Florida, Population: 19297822
# Name: Georgia, Population: 9901430
# Name: Hawaii, Population: 1394804
# Name: Idaho, Population: 1595324
# Name: Illinois, Population: 12882510
# Name: Indiana, Population: 6537703
# Name: Iowa, Population: 3076190
# Name: Kansas, Population: 2885257
# Name: Kentucky, Population: 4386346
# Name: Louisiana, Population: 4600972
# Name: Maine, Population: 1327729
# ...

# %%
one_percent_math =
# Out:
#       CSA     CBSA  MDIV    STCOU                               NAME  \
# 0     104      NaN   NaN      NaN             Albany-Schenectady, NY
# 1     104  10580.0   NaN      NaN        Albany-Schenectady-Troy, NY
# 2     104  10580.0   NaN  36001.0                  Albany County, NY
# 3     104  10580.0   NaN  36083.0              Rensselaer County, NY
# 4     104  10580.0   NaN  36091.0                Saratoga County, NY
# ...   ...      ...   ...      ...                                ...
# 1928  566  41400.0   NaN  39029.0              Columbiana County, OH
# 1929  566  49660.0   NaN      NaN  Youngstown-Warren-Boardman, OH-PA
# 1930  566  49660.0   NaN  39099.0                Mahoning County, OH
# 1931  566  49660.0   NaN  39155.0                Trumbull County, OH
# 1932  566  49660.0   NaN  42085.0                  Mercer County, PA
#
#                                LSAD  CENSUS2010POP  ESTIMATESBASE2010  \
# ...
