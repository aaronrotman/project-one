# %%
# Dependencies and set-up
import pandas as pd
import requests
import json
from config import api_key
from pprint import pprint
from datetime import date
from matplotlib import pyplot as plt
import numpy as np
import gmaps
from config import g_key

# %%
# Base url for Covid-19 statistics API
url = "https://covid-19-coronavirus-statistics.p.rapidapi.com/v1/stats"

# Query parameters
querystring = {"country":"US"}

headers = {
    'x-rapidapi-host': "covid-19-coronavirus-statistics.p.rapidapi.com",
    'x-rapidapi-key': api_key
    }


# Attempt to retrieve county level data for the United States
try:
    response = requests.get(url, headers=headers, params=querystring).json()
    
# Print error message if error occurs during API call
except:
    print('API call failed.')

# Pretty print the response
pprint(response)
# Out:
# {'data': {'covid19Stats': [{'city': 'Abbeville',
#                             'confirmed': 9,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Abbeville, South Carolina, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'South Carolina',
#                             'recovered': 0},
#                            {'city': 'Acadia',
#                             'confirmed': 104,
#                             'country': 'US',
#                             'deaths': 5,
#                             'keyId': 'Acadia, Louisiana, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Louisiana',
#                             'recovered': 0},
#                            {'city': 'Accomack',
#                             'confirmed': 15,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Accomack, Virginia, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Virginia',
#                             'recovered': 0},
#                            {'city': 'Ada',
#                             'confirmed': 538,
#                             'country': 'US',
#                             'deaths': 9,
#                             'keyId': 'Ada, Idaho, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Idaho',
#                             'recovered': 0},
#                            {'city': 'Adair',
#                             'confirmed': 1,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Adair, Iowa, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Iowa',
#                             'recovered': 0},
#                            {'city': 'Adair',
#                             'confirmed': 43,
#                             'country': 'US',
#                             'deaths': 1,
#                             'keyId': 'Adair, Kentucky, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Kentucky',
#                             'recovered': 0},
#                            {'city': 'Adair',
#                             'confirmed': 12,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Adair, Missouri, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Missouri',
#                             'recovered': 0},
#                            {'city': 'Adair',
#                             'confirmed': 28,
#                             'country': 'US',
#                             'deaths': 2,
#                             'keyId': 'Adair, Oklahoma, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Oklahoma',
#                             'recovered': 0},
#                            {'city': 'Adams',
#                             'confirmed': 726,
#                             'country': 'US',
#                             'deaths': 27,
#                             'keyId': 'Adams, Colorado, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Colorado',
#                             'recovered': 0},
#                            {'city': 'Adams',
#                             'confirmed': 1,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Adams, Idaho, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Idaho',
#                             'recovered': 0},
#                            {'city': 'Adams',
#                             'confirmed': 27,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Adams, Illinois, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Illinois',
#                             'recovered': 0},
#                            {'city': 'Adams',
#                             'confirmed': 6,
#                             'country': 'US',
#                             'deaths': 1,
#                             'keyId': 'Adams, Indiana, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Indiana',
#                             'recovered': 0},
#                            {'city': 'Adams',
#                             'confirmed': 62,
#                             'country': 'US',
#                             'deaths': 1,
#                             'keyId': 'Adams, Mississippi, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Mississippi',
#                             'recovered': 0},
#                            {'city': 'Adams',
#                             'confirmed': 62,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Adams, Nebraska, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Nebraska',
#                             'recovered': 0},
#                            {'city': 'Adams',
#                             'confirmed': 3,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Adams, Ohio, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Ohio',
#                             'recovered': 0},
#                            {'city': 'Adams',
#                             'confirmed': 63,
#                             'country': 'US',
#                             'deaths': 1,
#                             'keyId': 'Adams, Pennsylvania, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Pennsylvania',
#                             'recovered': 0},
#                            {'city': 'Adams',
#                             'confirmed': 39,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Adams, Washington, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Washington',
#                             'recovered': 0},
#                            {'city': 'Adams',
#                             'confirmed': 3,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Adams, Wisconsin, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Wisconsin',
#                             'recovered': 0},
#                            {'city': 'Addison',
#                             'confirmed': 56,
#                             'country': 'US',
#                             'deaths': 1,
#                             'keyId': 'Addison, Vermont, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Vermont',
#                             'recovered': 0},
#                            {'city': 'Aiken',
#                             'confirmed': 60,
#                             'country': 'US',
#                             'deaths': 3,
#                             'keyId': 'Aiken, South Carolina, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'South Carolina',
#                             'recovered': 0},
#                            {'city': 'Alachua',
#                             'confirmed': 195,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Alachua, Florida, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Florida',
#                             'recovered': 0},
#                            {'city': 'Alamance',
#                             'confirmed': 73,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Alamance, North Carolina, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'North Carolina',
#                             'recovered': 0},
#                            {'city': 'Alameda',
#                             'confirmed': 888,
#                             'country': 'US',
#                             'deaths': 23,
#                             'keyId': 'Alameda, California, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'California',
#                             'recovered': 0},
#                            {'city': 'Alamosa',
#                             'confirmed': 7,
#                             'country': 'US',
#                             'deaths': 2,
#                             'keyId': 'Alamosa, Colorado, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Colorado',
#                             'recovered': 0},
#                            {'city': 'Albany',
#                             'confirmed': 535,
#                             'country': 'US',
#                             'deaths': 16,
#                             'keyId': 'Albany, New York, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'New York',
#                             'recovered': 0},
#                            {'city': 'Albany',
#                             'confirmed': 5,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Albany, Wyoming, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Wyoming',
#                             'recovered': 0},
#                            {'city': 'Albemarle',
#                             'confirmed': 50,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Albemarle, Virginia, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Virginia',
#                             'recovered': 0},
#                            {'city': 'Alcorn',
#                             'confirmed': 7,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Alcorn, Mississippi, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Mississippi',
#                             'recovered': 0},
#                            {'city': 'Alexander',
#                             'confirmed': 3,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Alexander, North Carolina, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'North Carolina',
#                             'recovered': 0},
#                            {'city': 'Alexandria',
#                             'confirmed': 247,
#                             'country': 'US',
#                             'deaths': 1,
#                             'keyId': 'Alexandria, Virginia, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Virginia',
#                             'recovered': 0},
#                            {'city': 'Alfalfa',
#                             'confirmed': 1,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Alfalfa, Oklahoma, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Oklahoma',
#                             'recovered': 0},
#                            {'city': 'Allamakee',
#                             'confirmed': 24,
#                             'country': 'US',
#                             'deaths': 1,
#                             'keyId': 'Allamakee, Iowa, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Iowa',
#                             'recovered': 0},
#                            {'city': 'Allegan',
#                             'confirmed': 23,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Allegan, Michigan, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Michigan',
#                             'recovered': 0},
#                            {'city': 'Allegany',
#                             'confirmed': 17,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Allegany, Maryland, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Maryland',
#                             'recovered': 0},
#                            {'city': 'Allegany',
#                             'confirmed': 28,
#                             'country': 'US',
#                             'deaths': 1,
#                             'keyId': 'Allegany, New York, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'New York',
#                             'recovered': 0},
#                            {'city': 'Alleghany',
#                             'confirmed': 2,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Alleghany, North Carolina, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'North Carolina',
#                             'recovered': 0},
#                            {'city': 'Alleghany',
#                             'confirmed': 4,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Alleghany, Virginia, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Virginia',
#                             'recovered': 0},
#                            {'city': 'Allegheny',
#                             'confirmed': 893,
#                             'country': 'US',
#                             'deaths': 24,
#                             'keyId': 'Allegheny, Pennsylvania, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Pennsylvania',
#                             'recovered': 0},
#                            {'city': 'Allen',
#                             'confirmed': 167,
#                             'country': 'US',
#                             'deaths': 13,
#                             'keyId': 'Allen, Indiana, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Indiana',
#                             'recovered': 0},
#                            {'city': 'Allen',
#                             'confirmed': 2,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Allen, Kentucky, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Kentucky',
#                             'recovered': 0},
#                            {'city': 'Allen',
#                             'confirmed': 74,
#                             'country': 'US',
#                             'deaths': 8,
#                             'keyId': 'Allen, Louisiana, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Louisiana',
#                             'recovered': 0},
#                            {'city': 'Allen',
#                             'confirmed': 46,
#                             'country': 'US',
#                             'deaths': 4,
#                             'keyId': 'Allen, Ohio, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Ohio',
#                             'recovered': 0},
#                            {'city': 'Allendale',
#                             'confirmed': 5,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Allendale, South Carolina, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'South Carolina',
#                             'recovered': 0},
#                            {'city': 'Alpena',
#                             'confirmed': 1,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Alpena, Michigan, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Michigan',
#                             'recovered': 0},
#                            {'city': 'Alpine',
#                             'confirmed': 2,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Alpine, California, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'California',
#                             'recovered': 0},
#                            {'city': 'Amador',
#                             'confirmed': 7,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Amador, California, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'California',
#                             'recovered': 0},
#                            {'city': 'Amelia',
#                             'confirmed': 9,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Amelia, Virginia, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Virginia',
#                             'recovered': 0},
#                            {'city': 'Amherst',
#                             'confirmed': 10,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Amherst, Virginia, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Virginia',
#                             'recovered': 0},
#                            {'city': 'Amite',
#                             'confirmed': 14,
#                             'country': 'US',
#                             'deaths': 1,
#                             'keyId': 'Amite, Mississippi, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Mississippi',
#                             'recovered': 0},
#                            {'city': 'Anchorage',
#                             'confirmed': 136,
#                             'country': 'US',
#                             'deaths': 4,
#                             'keyId': 'Anchorage, Alaska, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Alaska',
#                             'recovered': 0},
#                            {'city': 'Anderson',
#                             'confirmed': 0,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Anderson, Kansas, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Kansas',
#                             'recovered': 0},
#                            {'city': 'Anderson',
#                             'confirmed': 3,
#                             'country': 'US',
#                             'deaths': 1,
#                             'keyId': 'Anderson, Kentucky, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Kentucky',
#                             'recovered': 0},
#                            {'city': 'Anderson',
#                             'confirmed': 111,
#                             'country': 'US',
#                             'deaths': 5,
#                             'keyId': 'Anderson, South Carolina, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'South Carolina',
#                             'recovered': 0},
#                            {'city': 'Anderson',
#                             'confirmed': 15,
#                             'country': 'US',
#                             'deaths': 1,
#                             'keyId': 'Anderson, Tennessee, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Tennessee',
#                             'recovered': 0},
#                            {'city': 'Anderson',
#                             'confirmed': 4,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Anderson, Texas, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Texas',
#                             'recovered': 0},
#                            {'city': 'Andrew',
#                             'confirmed': 1,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Andrew, Missouri, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Missouri',
#                             'recovered': 0},
#                            {'city': 'Andrews',
#                             'confirmed': 13,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Andrews, Texas, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Texas',
#                             'recovered': 0},
#                            {'city': 'Androscoggin',
#                             'confirmed': 29,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Androscoggin, Maine, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Maine',
#                             'recovered': 0},
#                            {'city': 'Angelina',
#                             'confirmed': 18,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Angelina, Texas, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Texas',
#                             'recovered': 0},
#                            {'city': 'Anne Arundel',
#                             'confirmed': 783,
#                             'country': 'US',
#                             'deaths': 32,
#                             'keyId': 'Anne Arundel, Maryland, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Maryland',
#                             'recovered': 0},
#                            {'city': 'Anoka',
#                             'confirmed': 72,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Anoka, Minnesota, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Minnesota',
#                             'recovered': 0},
#                            {'city': 'Anson',
#                             'confirmed': 11,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Anson, North Carolina, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'North Carolina',
#                             'recovered': 0},
#                            {'city': 'Antelope',
#                             'confirmed': 1,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Antelope, Nebraska, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Nebraska',
#                             'recovered': 0},
#                            {'city': 'Antrim',
#                             'confirmed': 8,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Antrim, Michigan, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Michigan',
#                             'recovered': 0},
#                            {'city': 'Apache',
#                             'confirmed': 97,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Apache, Arizona, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Arizona',
#                             'recovered': 0},
#                            {'city': 'Appanoose',
#                             'confirmed': 1,
#                             'country': 'US',
#                             'deaths': 1,
#                             'keyId': 'Appanoose, Iowa, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Iowa',
#                             'recovered': 0},
#                            {'city': 'Appling',
#                             'confirmed': 13,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Appling, Georgia, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Georgia',
#                             'recovered': 0},
#                            {'city': 'Appomattox',
#                             'confirmed': 7,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Appomattox, Virginia, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Virginia',
#                             'recovered': 0},
#                            {'city': 'Aransas',
#                             'confirmed': 2,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Aransas, Texas, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Texas',
#                             'recovered': 0},
#                            {'city': 'Arapahoe',
#                             'confirmed': 1183,
#                             'country': 'US',
#                             'deaths': 43,
#                             'keyId': 'Arapahoe, Colorado, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Colorado',
#                             'recovered': 0},
#                            {'city': 'Archuleta',
#                             'confirmed': 6,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Archuleta, Colorado, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Colorado',
#                             'recovered': 0},
#                            {'city': 'Arenac',
#                             'confirmed': 5,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Arenac, Michigan, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Michigan',
#                             'recovered': 0},
#                            {'city': 'Arkansas',
#                             'confirmed': 2,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Arkansas, Arkansas, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Arkansas',
#                             'recovered': 0},
#                            {'city': 'Arlington',
#                             'confirmed': 401,
#                             'country': 'US',
#                             'deaths': 2,
#                             'keyId': 'Arlington, Virginia, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Virginia',
#                             'recovered': 0},
#                            {'city': 'Armstrong',
#                             'confirmed': 28,
#                             'country': 'US',
#                             'deaths': 1,
#                             'keyId': 'Armstrong, Pennsylvania, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Pennsylvania',
#                             'recovered': 0},
#                            {'city': 'Armstrong',
#                             'confirmed': 1,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Armstrong, Texas, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Texas',
#                             'recovered': 0},
#                            {'city': 'Aroostook',
#                             'confirmed': 2,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Aroostook, Maine, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Maine',
#                             'recovered': 0},
#                            {'city': 'Ascension',
#                             'confirmed': 438,
#                             'country': 'US',
#                             'deaths': 27,
#                             'keyId': 'Ascension, Louisiana, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Louisiana',
#                             'recovered': 0},
#                            {'city': 'Ashe',
#                             'confirmed': 4,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Ashe, North Carolina, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'North Carolina',
#                             'recovered': 0},
#                            {'city': 'Ashland',
#                             'confirmed': 5,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Ashland, Ohio, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Ohio',
#                             'recovered': 0},
#                            {'city': 'Ashland',
#                             'confirmed': 2,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Ashland, Wisconsin, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Wisconsin',
#                             'recovered': 0},
#                            {'city': 'Ashley',
#                             'confirmed': 11,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Ashley, Arkansas, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Arkansas',
#                             'recovered': 0},
#                            {'city': 'Ashtabula',
#                             'confirmed': 32,
#                             'country': 'US',
#                             'deaths': 2,
#                             'keyId': 'Ashtabula, Ohio, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Ohio',
#                             'recovered': 0},
#                            {'city': 'Asotin',
#                             'confirmed': 6,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Asotin, Washington, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Washington',
#                             'recovered': 0},
#                            {'city': 'Assumption',
#                             'confirmed': 123,
#                             'country': 'US',
#                             'deaths': 1,
#                             'keyId': 'Assumption, Louisiana, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Louisiana',
#                             'recovered': 0},
#                            {'city': 'Atascosa',
#                             'confirmed': 9,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Atascosa, Texas, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Texas',
#                             'recovered': 0},
#                            {'city': 'Atchison',
#                             'confirmed': 3,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Atchison, Kansas, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Kansas',
#                             'recovered': 0},
#                            {'city': 'Atchison',
#                             'confirmed': 2,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Atchison, Missouri, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Missouri',
#                             'recovered': 0},
#                            {'city': 'Athens',
#                             'confirmed': 3,
#                             'country': 'US',
#                             'deaths': 1,
#                             'keyId': 'Athens, Ohio, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Ohio',
#                             'recovered': 0},
#                            {'city': 'Atkinson',
#                             'confirmed': 2,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Atkinson, Georgia, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Georgia',
#                             'recovered': 0},
#                            {'city': 'Atlantic',
#                             'confirmed': 284,
#                             'country': 'US',
#                             'deaths': 11,
#                             'keyId': 'Atlantic, New Jersey, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'New Jersey',
#                             'recovered': 0},
#                            {'city': 'Atoka',
#                             'confirmed': 1,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Atoka, Oklahoma, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Oklahoma',
#                             'recovered': 0},
#                            {'city': 'Attala',
#                             'confirmed': 22,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Attala, Mississippi, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Mississippi',
#                             'recovered': 0},
#                            {'city': 'Audubon',
#                             'confirmed': 1,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Audubon, Iowa, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Iowa',
#                             'recovered': 0},
#                            {'city': 'Auglaize',
#                             'confirmed': 15,
#                             'country': 'US',
#                             'deaths': 1,
#                             'keyId': 'Auglaize, Ohio, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Ohio',
#                             'recovered': 0},
#                            {'city': 'Augusta',
#                             'confirmed': 17,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Augusta, Virginia, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Virginia',
#                             'recovered': 0},
#                            {'city': 'Aurora',
#                             'confirmed': 1,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Aurora, South Dakota, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'South Dakota',
#                             'recovered': 0},
#                            {'city': 'Austin',
#                             'confirmed': 12,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Austin, Texas, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Texas',
#                             'recovered': 0},
#                            {'city': 'Autauga',
#                             'confirmed': 23,
#                             'country': 'US',
#                             'deaths': 1,
#                             'keyId': 'Autauga, Alabama, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Alabama',
#                             'recovered': 0},
#                            {'city': 'Avoyelles',
#                             'confirmed': 65,
#                             'country': 'US',
#                             'deaths': 2,
#                             'keyId': 'Avoyelles, Louisiana, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Louisiana',
#                             'recovered': 0},
#                            {'city': 'Baca',
#                             'confirmed': 10,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Baca, Colorado, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Colorado',
#                             'recovered': 0},
#                            {'city': 'Bacon',
#                             'confirmed': 14,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Bacon, Georgia, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Georgia',
#                             'recovered': 0},
#                            {'city': 'Baker',
#                             'confirmed': 17,
#                             'country': 'US',
#                             'deaths': 2,
#                             'keyId': 'Baker, Florida, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Florida',
#                             'recovered': 0},
#                            {'city': 'Baker',
#                             'confirmed': 16,
#                             'country': 'US',
#                             'deaths': 2,
#                             'keyId': 'Baker, Georgia, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Georgia',
#                             'recovered': 0},
#                            {'city': 'Baldwin',
#                             'confirmed': 87,
#                             'country': 'US',
#                             'deaths': 2,
#                             'keyId': 'Baldwin, Alabama, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Alabama',
#                             'recovered': 0},
#                            {'city': 'Baldwin',
#                             'confirmed': 69,
#                             'country': 'US',
#                             'deaths': 2,
#                             'keyId': 'Baldwin, Georgia, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Georgia',
#                             'recovered': 0},
#                            {'city': 'Ballard',
#                             'confirmed': 2,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Ballard, Kentucky, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Kentucky',
#                             'recovered': 0},
#                            {'city': 'Baltimore',
#                             'confirmed': 1377,
#                             'country': 'US',
#                             'deaths': 41,
#                             'keyId': 'Baltimore, Maryland, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Maryland',
#                             'recovered': 0},
#                            {'city': 'Baltimore City',
#                             'confirmed': 962,
#                             'country': 'US',
#                             'deaths': 29,
#                             'keyId': 'Baltimore City, Maryland, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Maryland',
#                             'recovered': 0},
#                            {'city': 'Bamberg',
#                             'confirmed': 7,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Bamberg, South Carolina, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'South Carolina',
#                             'recovered': 0},
#                            {'city': 'Bandera',
#                             'confirmed': 2,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Bandera, Texas, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Texas',
#                             'recovered': 0},
#                            {'city': 'Banks',
#                             'confirmed': 8,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Banks, Georgia, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Georgia',
#                             'recovered': 0},
#                            {'city': 'Bannock',
#                             'confirmed': 5,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Bannock, Idaho, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Idaho',
#                             'recovered': 0},
#                            {'city': 'Barber',
#                             'confirmed': 1,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Barber, Kansas, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Kansas',
#                             'recovered': 0},
#                            {'city': 'Barbour',
#                             'confirmed': 11,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Barbour, Alabama, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Alabama',
#                             'recovered': 0},
#                            {'city': 'Barbour',
#                             'confirmed': 4,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Barbour, West Virginia, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'West Virginia',
#                             'recovered': 0},
#                            {'city': 'Barnes',
#                             'confirmed': 2,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Barnes, North Dakota, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'North Dakota',
#                             'recovered': 0},
#                            {'city': 'Barnstable',
#                             'confirmed': 514,
#                             'country': 'US',
#                             'deaths': 16,
#                             'keyId': 'Barnstable, Massachusetts, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Massachusetts',
#                             'recovered': 0},
#                            {'city': 'Barnwell',
#                             'confirmed': 5,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Barnwell, South Carolina, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'South Carolina',
#                             'recovered': 0},
#                            {'city': 'Barren',
#                             'confirmed': 5,
# ...
#                             'keyId': 'Worth, Missouri, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Missouri',
#                             'recovered': 0},
#                            {'city': 'Wright',
#                             'confirmed': 1,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Wright, Iowa, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Iowa',
#                             'recovered': 0},
#                            {'city': 'Wright',
#                             'confirmed': 19,
#                             'country': 'US',
#                             'deaths': 1,
#                             'keyId': 'Wright, Minnesota, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Minnesota',
#                             'recovered': 0},
#                            {'city': 'Wright',
#                             'confirmed': 9,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Wright, Missouri, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Missouri',
#                             'recovered': 0},
#                            {'city': 'Wyandot',
#                             'confirmed': 13,
#                             'country': 'US',
#                             'deaths': 2,
#                             'keyId': 'Wyandot, Ohio, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Ohio',
#                             'recovered': 0},
#                            {'city': 'Wyandotte',
#                             'confirmed': 345,
#                             'country': 'US',
#                             'deaths': 30,
#                             'keyId': 'Wyandotte, Kansas, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Kansas',
#                             'recovered': 0},
#                            {'city': 'Wyoming',
#                             'confirmed': 32,
#                             'country': 'US',
#                             'deaths': 1,
#                             'keyId': 'Wyoming, New York, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'New York',
#                             'recovered': 0},
#                            {'city': 'Wyoming',
#                             'confirmed': 11,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Wyoming, Pennsylvania, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Pennsylvania',
#                             'recovered': 0},
#                            {'city': 'Wyoming',
#                             'confirmed': 1,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Wyoming, West Virginia, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'West Virginia',
#                             'recovered': 0},
#                            {'city': 'Wythe',
#                             'confirmed': 7,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Wythe, Virginia, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Virginia',
#                             'recovered': 0},
#                            {'city': 'Yadkin',
#                             'confirmed': 14,
#                             'country': 'US',
#                             'deaths': 1,
#                             'keyId': 'Yadkin, North Carolina, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'North Carolina',
#                             'recovered': 0},
#                            {'city': 'Yakima',
#                             'confirmed': 614,
#                             'country': 'US',
#                             'deaths': 25,
#                             'keyId': 'Yakima, Washington, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Washington',
#                             'recovered': 0},
#                            {'city': 'Yalobusha',
#                             'confirmed': 14,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Yalobusha, Mississippi, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Mississippi',
#                             'recovered': 0},
#                            {'city': 'Yamhill',
#                             'confirmed': 32,
#                             'country': 'US',
#                             'deaths': 6,
#                             'keyId': 'Yamhill, Oregon, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Oregon',
#                             'recovered': 0},
#                            {'city': 'Yankton',
#                             'confirmed': 22,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Yankton, South Dakota, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'South Dakota',
#                             'recovered': 0},
#                            {'city': 'Yates',
#                             'confirmed': 6,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Yates, New York, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'New York',
#                             'recovered': 0},
#                            {'city': 'Yavapai',
#                             'confirmed': 70,
#                             'country': 'US',
#                             'deaths': 1,
#                             'keyId': 'Yavapai, Arizona, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Arizona',
#                             'recovered': 0},
#                            {'city': 'Yazoo',
#                             'confirmed': 64,
#                             'country': 'US',
#                             'deaths': 1,
#                             'keyId': 'Yazoo, Mississippi, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Mississippi',
#                             'recovered': 0},
#                            {'city': 'Yell',
#                             'confirmed': 1,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Yell, Arkansas, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Arkansas',
#                             'recovered': 0},
#                            {'city': 'Yellow Medicine',
#                             'confirmed': 3,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Yellow Medicine, Minnesota, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Minnesota',
#                             'recovered': 0},
#                            {'city': 'Yellowstone',
#                             'confirmed': 63,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Yellowstone, Montana, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Montana',
#                             'recovered': 0},
#                            {'city': 'Yolo',
#                             'confirmed': 101,
#                             'country': 'US',
#                             'deaths': 4,
#                             'keyId': 'Yolo, California, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'California',
#                             'recovered': 0},
#                            {'city': 'York',
#                             'confirmed': 152,
#                             'country': 'US',
#                             'deaths': 4,
#                             'keyId': 'York, Maine, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Maine',
#                             'recovered': 0},
#                            {'city': 'York',
#                             'confirmed': 4,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'York, Nebraska, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Nebraska',
#                             'recovered': 0},
#                            {'city': 'York',
#                             'confirmed': 371,
#                             'country': 'US',
#                             'deaths': 3,
#                             'keyId': 'York, Pennsylvania, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Pennsylvania',
#                             'recovered': 0},
#                            {'city': 'York',
#                             'confirmed': 138,
#                             'country': 'US',
#                             'deaths': 3,
#                             'keyId': 'York, South Carolina, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'South Carolina',
#                             'recovered': 0},
#                            {'city': 'York',
#                             'confirmed': 35,
#                             'country': 'US',
#                             'deaths': 1,
#                             'keyId': 'York, Virginia, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Virginia',
#                             'recovered': 0},
#                            {'city': 'Young',
#                             'confirmed': 3,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Young, Texas, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Texas',
#                             'recovered': 0},
#                            {'city': 'Yuba',
#                             'confirmed': 15,
#                             'country': 'US',
#                             'deaths': 1,
#                             'keyId': 'Yuba, California, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'California',
#                             'recovered': 0},
#                            {'city': 'Yukon-Koyukuk',
#                             'confirmed': 1,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Yukon-Koyukuk, Alaska, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Alaska',
#                             'recovered': 0},
#                            {'city': 'Yuma',
#                             'confirmed': 20,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Yuma, Arizona, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Arizona',
#                             'recovered': 0},
#                            {'city': 'Yuma',
#                             'confirmed': 2,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Yuma, Colorado, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Colorado',
#                             'recovered': 0},
#                            {'city': 'Zapata',
#                             'confirmed': 3,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Zapata, Texas, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Texas',
#                             'recovered': 0},
#                            {'city': '',
#                             'confirmed': 49,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Diamond Princess, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Diamond Princess',
#                             'recovered': 0},
#                            {'city': '',
#                             'confirmed': 103,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Grand Princess, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Grand Princess',
#                             'recovered': 0},
#                            {'city': '',
#                             'confirmed': 133,
#                             'country': 'US',
#                             'deaths': 5,
#                             'keyId': 'Guam, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Guam',
#                             'recovered': 0},
#                            {'city': '',
#                             'confirmed': 6,
#                             'country': 'US',
#                             'deaths': 1,
#                             'keyId': 'Northern Mariana Islands, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Northern Mariana Islands',
#                             'recovered': 0},
#                            {'city': '',
#                             'confirmed': 923,
#                             'country': 'US',
#                             'deaths': 45,
#                             'keyId': 'Puerto Rico, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Puerto Rico',
#                             'recovered': 0},
#                            {'city': '',
#                             'confirmed': 0,
#                             'country': 'US',
#                             'deaths': 0,
#                             'keyId': 'Recovered, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Recovered',
#                             'recovered': 47763},
#                            {'city': '',
#                             'confirmed': 51,
#                             'country': 'US',
#                             'deaths': 1,
#                             'keyId': 'Virgin Islands, US',
#                             'lastUpdate': '2020-04-14 23:33:31',
#                             'province': 'Virgin Islands',
#                             'recovered': 0}],
#           'lastChecked': '2020-04-15T21:06:19.576Z'},
#  'error': False,
#  'message': 'OK',
#  'statusCode': 200}

# %%
# List of county data from every US county
county_data =[county for county in response['data']['covid19Stats']]

# Data frame of statistics for each county in the United States
usa_df = pd.DataFrame(county_data)

# Clean up the column names
renamed_usa_df = usa_df.rename(columns={
    'city': 'County',
    'province': 'State',
    'country': 'Country',
    'lastUpdate': 'Date',
    'keyId': 'Key ID',
    'confirmed': 'Confirmed Cases',
    'deaths': 'Deaths',
    'recovered': 'Recovered'
})

# View the cleaned up data frame
renamed_usa_df
# Out:
#          County                     State Country                 Date  \
# 0     Abbeville            South Carolina      US  2020-04-14 23:33:31
# 1        Acadia                 Louisiana      US  2020-04-14 23:33:31
# 2      Accomack                  Virginia      US  2020-04-14 23:33:31
# 3           Ada                     Idaho      US  2020-04-14 23:33:31
# 4         Adair                      Iowa      US  2020-04-14 23:33:31
# ...         ...                       ...     ...                  ...
# 2747                                 Guam      US  2020-04-14 23:33:31
# 2748             Northern Mariana Islands      US  2020-04-14 23:33:31
# 2749                          Puerto Rico      US  2020-04-14 23:33:31
# 2750                            Recovered      US  2020-04-14 23:33:31
# 2751                       Virgin Islands      US  2020-04-14 23:33:31
#
#                              Key ID  Confirmed Cases  Deaths  Recovered
# 0     Abbeville, South Carolina, US                9       0          0
# 1             Acadia, Louisiana, US              104       5          0
# 2            Accomack, Virginia, US               15       0          0
# 3                    Ada, Idaho, US              538       9          0
# 4                   Adair, Iowa, US                1       0          0
# ...                             ...              ...     ...        ...
# 2747                       Guam, US              133       5          0
# 2748   Northern Mariana Islands, US                6       1          0
# 2749                Puerto Rico, US              923      45          0
# 2750                  Recovered, US                0       0      47763
# 2751             Virgin Islands, US               51       1          0
#
# [2752 rows x 8 columns]

# %%
# Replace empty string values with NaN
renamed_usa_df.replace('', np.nan, inplace=True)
renamed_usa_df
# Out:
#          County                     State Country                 Date  \
# 0     Abbeville            South Carolina      US  2020-04-14 23:33:31
# 1        Acadia                 Louisiana      US  2020-04-14 23:33:31
# 2      Accomack                  Virginia      US  2020-04-14 23:33:31
# 3           Ada                     Idaho      US  2020-04-14 23:33:31
# 4         Adair                      Iowa      US  2020-04-14 23:33:31
# ...         ...                       ...     ...                  ...
# 2747        NaN                      Guam      US  2020-04-14 23:33:31
# 2748        NaN  Northern Mariana Islands      US  2020-04-14 23:33:31
# 2749        NaN               Puerto Rico      US  2020-04-14 23:33:31
# 2750        NaN                 Recovered      US  2020-04-14 23:33:31
# 2751        NaN            Virgin Islands      US  2020-04-14 23:33:31
#
#                              Key ID  Confirmed Cases  Deaths  Recovered
# 0     Abbeville, South Carolina, US                9       0          0
# 1             Acadia, Louisiana, US              104       5          0
# 2            Accomack, Virginia, US               15       0          0
# 3                    Ada, Idaho, US              538       9          0
# 4                   Adair, Iowa, US                1       0          0
# ...                             ...              ...     ...        ...
# 2747                       Guam, US              133       5          0
# 2748   Northern Mariana Islands, US                6       1          0
# 2749                Puerto Rico, US              923      45          0
# 2750                  Recovered, US                0       0      47763
# 2751             Virgin Islands, US               51       1          0
#
# [2752 rows x 8 columns]

# %%
# Drop rows with NaN values
dropped_usa_df = renamed_usa_df.dropna()
dropped_usa_df
# Out:
#              County           State Country                 Date  \
# 0         Abbeville  South Carolina      US  2020-04-14 23:33:31
# 1            Acadia       Louisiana      US  2020-04-14 23:33:31
# 2          Accomack        Virginia      US  2020-04-14 23:33:31
# 3               Ada           Idaho      US  2020-04-14 23:33:31
# 4             Adair            Iowa      US  2020-04-14 23:33:31
# ...             ...             ...     ...                  ...
# 2740           Yuba      California      US  2020-04-14 23:33:31
# 2741  Yukon-Koyukuk          Alaska      US  2020-04-14 23:33:31
# 2742           Yuma         Arizona      US  2020-04-14 23:33:31
# 2743           Yuma        Colorado      US  2020-04-14 23:33:31
# 2744         Zapata           Texas      US  2020-04-14 23:33:31
#
#                              Key ID  Confirmed Cases  Deaths  Recovered
# 0     Abbeville, South Carolina, US                9       0          0
# 1             Acadia, Louisiana, US              104       5          0
# 2            Accomack, Virginia, US               15       0          0
# 3                    Ada, Idaho, US              538       9          0
# 4                   Adair, Iowa, US                1       0          0
# ...                             ...              ...     ...        ...
# 2740           Yuba, California, US               15       1          0
# 2741      Yukon-Koyukuk, Alaska, US                1       0          0
# 2742              Yuma, Arizona, US               20       0          0
# 2743             Yuma, Colorado, US                2       0          0
# 2744              Zapata, Texas, US                3       0          0
#
# [2745 rows x 8 columns]

# %%
# View a list of unique state names
unique_states = dropped_usa_df['State'].unique()
unique_states
# Out:
# array(['South Carolina', 'Louisiana', 'Virginia', 'Idaho', 'Iowa',
#        'Kentucky', 'Missouri', 'Oklahoma', 'Colorado', 'Illinois',
#        'Indiana', 'Mississippi', 'Nebraska', 'Ohio', 'Pennsylvania',
#        'Washington', 'Wisconsin', 'Vermont', 'Florida', 'North Carolina',
#        'California', 'New York', 'Wyoming', 'Michigan', 'Maryland',
#        'Alaska', 'Kansas', 'Tennessee', 'Texas', 'Maine', 'Minnesota',
#        'Arizona', 'Georgia', 'Arkansas', 'New Jersey', 'South Dakota',
#        'Alabama', 'West Virginia', 'North Dakota', 'Massachusetts',
#        'Montana', 'New Hampshire', 'Oregon', 'New Mexico', 'Utah',
#        'Rhode Island', 'Nevada', 'District of Columbia', 'Connecticut',
#        'Hawaii', 'Delaware', 'Northern Mariana Islands'], dtype=object)

# %%
# Create a list of the unique state names
unique_states_list = list(unique_states)

# %%
# Remove any rows where the state is 'Northern Mariana Islands' of 'District of Columbia'
unique_states_list.remove('Northern Mariana Islands')
unique_states_list.remove('District of Columbia')

# %%
# View the list of states in alphabetical order
fifty_states = sorted(unique_states_list)
fifty_states
# Out:
# ['Alabama',
#  'Alaska',
#  'Arizona',
#  'Arkansas',
#  'California',
#  'Colorado',
#  'Connecticut',
#  'Delaware',
#  'Florida',
#  'Georgia',
#  'Hawaii',
#  'Idaho',
#  'Illinois',
#  'Indiana',
#  'Iowa',
#  'Kansas',
#  'Kentucky',
#  'Louisiana',
#  'Maine',
#  'Maryland',
#  'Massachusetts',
#  'Michigan',
#  'Minnesota',
#  'Mississippi',
#  'Missouri',
#  'Montana',
#  'Nebraska',
#  'Nevada',
#  'New Hampshire',
#  'New Jersey',
#  'New Mexico',
#  'New York',
#  'North Carolina',
#  'North Dakota',
#  'Ohio',
#  'Oklahoma',
#  'Oregon',
#  'Pennsylvania',
#  'Rhode Island',
#  'South Carolina',
#  'South Dakota',
#  'Tennessee',
#  'Texas',
#  'Utah',
#  'Vermont',
#  'Virginia',
#  'Washington',
#  'West Virginia',
#  'Wisconsin',
#  'Wyoming']

# %%
# Import U.S. Census population data for the United States from a .csv
population_data = pd.read_csv('Resources/county_population_data.csv', encoding='iso-8859-1')
# Dataframe of the .csv
population_df = pd.DataFrame(population_data)
# Dataframe of just county and 2019 population estimate columns
county_pop_df = population_df[['CTYNAME', 'POPESTIMATE2019']]
# Rename columns
county_pop_df.columns = ['County', 'Population']
county_pop_df
# Out:
#                  County  Population
# 0               Alabama     4903185
# 1        Autauga County       55869
# 2        Baldwin County      223234
# 3        Barbour County       24686
# 4           Bibb County       22394
# ...                 ...         ...
# 3188  Sweetwater County       42343
# 3189       Teton County       23464
# 3190       Uinta County       20226
# 3191    Washakie County        7805
# 3192      Weston County        6927
#
# [3193 rows x 2 columns]

# %%
# Create dataframe from the list of U.S. states 
fifty_states_df = pd.DataFrame(fifty_states)
# Rename column
fifty_states_df.columns = ['County']
# Combine the state names and populations into a single data frame
state_pop_df = fifty_states_df.merge(county_pop_df, on='County', how='left')
# Rename columns
state_pop_df.columns = ['State', 'Population']
state_pop_df
# Out:
#              State  Population
# 0          Alabama     4903185
# 1           Alaska      731545
# 2          Arizona     7278717
# 3         Arkansas     3017804
# 4       California    39512223
# 5         Colorado     5758736
# 6      Connecticut     3565287
# 7         Delaware      973764
# 8          Florida    21477737
# 9          Georgia    10617423
# 10          Hawaii     1415872
# 11           Idaho     1787065
# 12        Illinois    12671821
# 13         Indiana     6732219
# 14            Iowa     3155070
# 15          Kansas     2913314
# 16        Kentucky     4467673
# 17       Louisiana     4648794
# 18           Maine     1344212
# 19        Maryland     6045680
# 20   Massachusetts     6892503
# 21        Michigan     9986857
# 22       Minnesota     5639632
# 23     Mississippi     2976149
# 24        Missouri     6137428
# 25         Montana     1068778
# 26        Nebraska     1934408
# 27          Nevada     3080156
# 28   New Hampshire     1359711
# 29      New Jersey     8882190
# 30      New Mexico     2096829
# 31        New York    19453561
# 32  North Carolina    10488084
# 33    North Dakota      762062
# 34            Ohio    11689100
# 35        Oklahoma     3956971
# 36          Oregon     4217737
# 37    Pennsylvania    12801989
# 38    Rhode Island     1059361
# 39  South Carolina     5148714
# 40    South Dakota      884659
# 41       Tennessee     6829174
# 42           Texas    28995881
# 43            Utah     3205958
# 44         Vermont      623989
# 45        Virginia     8535519
# 46      Washington     7614893
# 47   West Virginia     1792147
# 48       Wisconsin     5822434
# 49         Wyoming      578759

# %%
# Group the Covid-19 USA dataframe by state
grouped_states = renamed_usa_df.groupby('State')
# Sum the total values for for each state and reset the index
state_totals = grouped_states.sum().reset_index()
# View the dataframe
state_totals
# Out:
#                        State  Confirmed Cases  Deaths  Recovered
# 0                    Alabama             3953     114          0
# 1                     Alaska              285       9          0
# 2                    Arizona             3809     131          0
# 3                   Arkansas             1498      32          0
# 4                 California            25356     768          0
# 5                   Colorado             7950     327          0
# 6                Connecticut            13989     671          0
# 7                   Delaware             1926      43          0
# 8           Diamond Princess               49       0          0
# 9       District of Columbia             2058      67          0
# 10                   Florida            21628     571          0
# 11                   Georgia            14578     525          0
# 12            Grand Princess              103       0          0
# 13                      Guam              133       5          0
# 14                    Hawaii              511       9          0
# 15                     Idaho             1464      33          0
# 16                  Illinois            23248     868          0
# 17                   Indiana             8527     387          0
# 18                      Iowa             1899      49          0
# 19                    Kansas             1441      69          0
# 20                  Kentucky             2048     106          0
# 21                 Louisiana            21518    1013          0
# 22                     Maine              735      20          0
# 23                  Maryland             9472     302          0
# 24             Massachusetts            28164     844          0
# 25                  Michigan            27001    1768          0
# 26                 Minnesota             1695      79          0
# 27               Mississippi             3087     111          0
# 28                  Missouri             4746     149          0
# 29                   Montana              399       7          0
# 30                  Nebraska              897      20          0
# 31                    Nevada             3134     126          0
# 32             New Hampshire              922      25          0
# 33                New Jersey            68824    2805          0
# 34                New Mexico             1345      31          0
# 35                  New York           203020   10842          0
# 36            North Carolina             5113     112          0
# 37              North Dakota              341       8          0
# 38  Northern Mariana Islands               11       2          0
# 39                      Ohio             7285     324          0
# 40                  Oklahoma             2184     108          0
# 41                    Oregon             1633      55          0
# 42              Pennsylvania            25465     691          0
# 43               Puerto Rico              923      45          0
# 44                 Recovered                0       0      47763
# 45              Rhode Island             3251      80          0
# 46            South Carolina             3553      97          0
# 47              South Dakota              988       6          0
# 48                 Tennessee             5827     124          0
# 49                     Texas            15006     342          0
# 50                      Utah             2417      18          0
# 51                   Vermont              752      29          0
# 52            Virgin Islands               51       1          0
# 53                  Virginia             6182     154          0
# 54                Washington            10799     530          0
# 55             West Virginia              640       9          0
# 56                 Wisconsin             3555     170          0
# 57                   Wyoming              282       1          0

# %%
# Merge the Covid-19 data with the state population data
covid_pop_df = state_pop_df.merge(state_totals, on='State', how='left')
# Delete the 'Recovered' column
del covid_pop_df['Recovered']
# Export the dataframe to a .csv
covid_pop_df.to_csv('Resources/covid_pop.csv', index=False)
covid_pop_df
# Out:
#              State  Population  Confirmed Cases  Deaths
# 0          Alabama     4903185             3953     114
# 1           Alaska      731545              285       9
# 2          Arizona     7278717             3809     131
# 3         Arkansas     3017804             1498      32
# 4       California    39512223            25356     768
# 5         Colorado     5758736             7950     327
# 6      Connecticut     3565287            13989     671
# 7         Delaware      973764             1926      43
# 8          Florida    21477737            21628     571
# 9          Georgia    10617423            14578     525
# 10          Hawaii     1415872              511       9
# 11           Idaho     1787065             1464      33
# 12        Illinois    12671821            23248     868
# 13         Indiana     6732219             8527     387
# 14            Iowa     3155070             1899      49
# 15          Kansas     2913314             1441      69
# 16        Kentucky     4467673             2048     106
# 17       Louisiana     4648794            21518    1013
# 18           Maine     1344212              735      20
# 19        Maryland     6045680             9472     302
# 20   Massachusetts     6892503            28164     844
# 21        Michigan     9986857            27001    1768
# 22       Minnesota     5639632             1695      79
# 23     Mississippi     2976149             3087     111
# 24        Missouri     6137428             4746     149
# 25         Montana     1068778              399       7
# 26        Nebraska     1934408              897      20
# 27          Nevada     3080156             3134     126
# 28   New Hampshire     1359711              922      25
# 29      New Jersey     8882190            68824    2805
# 30      New Mexico     2096829             1345      31
# 31        New York    19453561           203020   10842
# 32  North Carolina    10488084             5113     112
# 33    North Dakota      762062              341       8
# 34            Ohio    11689100             7285     324
# 35        Oklahoma     3956971             2184     108
# 36          Oregon     4217737             1633      55
# 37    Pennsylvania    12801989            25465     691
# 38    Rhode Island     1059361             3251      80
# 39  South Carolina     5148714             3553      97
# 40    South Dakota      884659              988       6
# 41       Tennessee     6829174             5827     124
# 42           Texas    28995881            15006     342
# 43            Utah     3205958             2417      18
# 44         Vermont      623989              752      29
# 45        Virginia     8535519             6182     154
# 46      Washington     7614893            10799     530
# 47   West Virginia     1792147              640       9
# 48       Wisconsin     5822434             3555     170
# 49         Wyoming      578759              282       1

# %%
# Add columns for cases and deaths per 100,000 residents
covid_pop_df['Cases Per 100,000'] = covid_pop_df['Confirmed Cases']/covid_pop_df['Population']*100000
covid_pop_df['Deaths Per 100,000'] = covid_pop_df['Deaths']/covid_pop_df['Population']*100000
covid_pop_df
# Out:
#              State  Population  Confirmed Cases  Deaths  Cases Per 100,000  \
# 0          Alabama     4903185             3953     114          80.621066
# 1           Alaska      731545              285       9          38.958642
# 2          Arizona     7278717             3809     131          52.330651
# 3         Arkansas     3017804             1498      32          49.638744
# 4       California    39512223            25356     768          64.172547
# 5         Colorado     5758736             7950     327         138.051128
# 6      Connecticut     3565287            13989     671         392.366730
# 7         Delaware      973764             1926      43         197.789197
# 8          Florida    21477737            21628     571         100.699622
# 9          Georgia    10617423            14578     525         137.302620
# 10          Hawaii     1415872              511       9          36.090833
# 11           Idaho     1787065             1464      33          81.922034
# 12        Illinois    12671821            23248     868         183.462187
# 13         Indiana     6732219             8527     387         126.659575
# 14            Iowa     3155070             1899      49          60.188839
# 15          Kansas     2913314             1441      69          49.462571
# 16        Kentucky     4467673             2048     106          45.840418
# 17       Louisiana     4648794            21518    1013         462.872736
# 18           Maine     1344212              735      20          54.678875
# 19        Maryland     6045680             9472     302         156.673856
# 20   Massachusetts     6892503            28164     844         408.617885
# 21        Michigan     9986857            27001    1768         270.365341
# 22       Minnesota     5639632             1695      79          30.055153
# 23     Mississippi     2976149             3087     111         103.724646
# 24        Missouri     6137428             4746     149          77.328809
# 25         Montana     1068778              399       7          37.332355
# 26        Nebraska     1934408              897      20          46.370776
# 27          Nevada     3080156             3134     126         101.748093
# 28   New Hampshire     1359711              922      25          67.808527
# 29      New Jersey     8882190            68824    2805         774.853949
# 30      New Mexico     2096829             1345      31          64.144477
# 31        New York    19453561           203020   10842        1043.613557
# 32  North Carolina    10488084             5113     112          48.750563
# 33    North Dakota      762062              341       8          44.747015
# 34            Ohio    11689100             7285     324          62.323019
# 35        Oklahoma     3956971             2184     108          55.193733
# 36          Oregon     4217737             1633      55          38.717445
# 37    Pennsylvania    12801989            25465     691         198.914403
# 38    Rhode Island     1059361             3251      80         306.883112
# 39  South Carolina     5148714             3553      97          69.007523
# 40    South Dakota      884659              988       6         111.681450
# 41       Tennessee     6829174             5827     124          85.325107
# 42           Texas    28995881            15006     342          51.752178
# 43            Utah     3205958             2417      18          75.390882
# 44         Vermont      623989              752      29         120.514945
# 45        Virginia     8535519             6182     154          72.426762
# 46      Washington     7614893            10799     530         141.814205
# 47   West Virginia     1792147              640       9          35.711356
# 48       Wisconsin     5822434             3555     170          61.056939
# 49         Wyoming      578759              282       1          48.724944
#
#     Deaths Per 100,000
# 0             2.325019
# 1             1.230273
# 2             1.799768
# 3             1.060374
# 4             1.943702
# 5             5.678329
# 6            18.820364
# 7             4.415854
# 8             2.658567
# 9             4.944703
# 10            0.635651
# 11            1.846603
# 12            6.849844
# 13            5.748476
# 14            1.553056
# 15            2.368437
# 16            2.372600
# 17           21.790598
# 18            1.487861
# 19            4.995302
# 20           12.245189
# 21           17.703267
# 22            1.400801
# 23            3.729652
# 24            2.427727
# 25            0.654954
# 26            1.033908
# 27            4.090702
# 28            1.838626
# 29           31.580050
# 30            1.478423
# 31           55.732727
# 32            1.067879
# 33            1.049783
# 34            2.771813
# 35            2.729360
# 36            1.304017
# 37            5.397599
# 38            7.551722
# 39            1.883966
# 40            0.678227
# 41            1.815739
# 42            1.179478
# 43            0.561455
# 44            4.647518
# 45            1.804225
# 46            6.960045
# 47            0.502191
# 48            2.919741
# 49            0.172783

# %%
# Sort the dataframe and store the results

#Sort dataframe by number of cases
by_case_num = covid_pop_df.sort_values('Confirmed Cases', ascending=False).reset_index(drop=True)
#Sort dataframe by cases per capita
by_case_per = covid_pop_df.sort_values('Cases Per 100,000', ascending=False).reset_index(drop=True)
#Sort dataframe by number of deaths
by_death_num = covid_pop_df.sort_values('Deaths', ascending=False).reset_index(drop=True)
#Sort dataframe by deaths per capita
by_death_per = covid_pop_df.sort_values('Deaths Per 100,000', ascending=False).reset_index(drop=True)

# %%
# Store the top ten states sorted for each value

# Top 10 states by number of cases
top_cases = by_case_num.head(10)

# Top 10 states by cases per 100,000 residents
top_cases_per = by_case_per.head(10)

# Top 10 states by number of deaths
top_deaths = by_death_num.head(10)

# Top 10 States by deaths per 100,000 residents
top_deaths_per = by_death_per.head(10)

# %%
# Plot the number of deaths per 100,000 residents for each of the top ten states based on total death number
plt.bar(top_deaths['State'], top_deaths['Deaths Per 100,000'])

# Format x-tick label
plt.xticks(ha='right', rotation=45)

# Axis labels
plt.xlabel('Top Ten States (by total number of deaths)')
plt.ylabel('Number of Deaths (per 100,000 residents)')
plt.title('''
Number of Deaths per 100,000 Residents 
for the Top Ten States
Ranked by Total Number of Deaths
''')

# Export plot as .png
plt.savefig('Resources/top_deaths.png', bbox_inches='tight')

plt.show()

# %%
# Plot the number of cases per 100,000 for each of the top ten states based on total case case number
plt.bar(top_cases['State'], top_cases['Cases Per 100,000'])

# Format x-tick label
plt.xticks(ha='right', rotation=45)

# Axis labels
plt.xlabel('Top Ten States (by total number of cases)')
plt.ylabel('Number of Cases (per 100,000 residents)')
plt.title('''
Number of Cases per 100,000 Residents 
for the Top Ten States
Ranked by Total Number of Casess
''')
# Export plot as .png
plt.savefig('Resources/top_cases.png', bbox_inches='tight')

plt.show()

# %%
state_coords = pd.read_csv('../../state_coordinates.csv')
state_coords.columns = ['Abbr', 'Lat', 'Long', 'State']
stats_locations = covid_pop_df.merge(state_coords, on='State', how='left')
stats_locations

#Configure gmaps with api key
gmaps.configure(api_key=g_key)

#Store the lat/long values for each state
locations = stats_locations[['Lat', 'Long']].astype(float)

#Store the death per 100,000 values for each state
deaths_per_capita = stats_locations['Deaths Per 100,000'].astype(float)


# Create a heatmap of deaths per 100,000 for each state
fig = gmaps.figure()

#Create the heat map layer
death_layer = gmaps.heatmap_layer(locations, weights=deaths_per_capita, 
                                 dissipating=False, max_intensity=deaths_per_capita.max(),
                                 point_radius = 1)
#Add the heat map layer to the figure
fig.add_layer(death_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Add the state markers to the heatmap
info_box_template = """
<dl>
<dt>Deaths Per 100,000</dt><dd>{Deaths Per 100,000}</dd>
<dt>State</dt><dd>{State}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
state_info = [info_box_template.format(**row) for index, row in stats_locations.iterrows()]

# Create symbol layer
symbol_layer = gmaps.marker_layer(
    locations,
    info_box_content=state_info)

#Create a combined map of the heat map and hotel symbol layers
fig = gmaps.figure()

#Add the heat map and hotel symbol layers

fig.add_layer(symbol_layer)
fig.add_layer(death_layer)
#Display the combined map
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
